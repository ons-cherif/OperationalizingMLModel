# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.20.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-138899
# aml-quickstarts-138899
# southcentralus
# f5091c60-1c3c-430f-8d81-d802f6bf2414

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'BankMarketingExperiment'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: BankMarketingExperiment,
# Workspace: quick-starts-ws-138899)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "MarketingCluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketingDataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_BankMarketing',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_BankMarketing [d0c23823][2ac9cab0-7563-4098-8f50-5c787585dc03], (This step will run and generate new outputs)
# Submitted PipelineRun b6313294-a5f5-458e-a737-a1727fc5aa2e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/BankMarketingExperiment/runs/b6313294-a5f5-458e-a737-a1727fc5aa2e?wsid=/subscriptions/f5091c60-1c3c-430f-8d81-d802f6bf2414/resourcegroups/aml-quickstarts-138899/workspaces/quick-starts-ws-138899

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: b6313294-a5f5-458e-a737-a1727fc5aa2e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/BankMarketingExperiment/runs/b6313294-a5f5-458e-a737-a1727fc5aa2e?wsid=/subscriptions/f5091c60-1c3c-430f-8d81-d802f6bf2414/resourcegroups/aml-quickstarts-138899/workspaces/quick-starts-ws-138899
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: abe34885-9b26-4229-a90b-116146bc5664
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/BankMarketingExperiment/runs/abe34885-9b26-4229-a90b-116146bc5664?wsid=/subscriptions/f5091c60-1c3c-430f-8d81-d802f6bf2414/resourcegroups/aml-quickstarts-138899/workspaces/quick-starts-ws-138899
# StepRun( automl_BankMarketing ) Status: NotStarted
# StepRun( automl_BankMarketing ) Status: Running
#
# StepRun(automl_BankMarketing) Execution Summary
# ================================================
# StepRun( automl_BankMarketing ) Status: Finished
# {'runId': 'abe34885-9b26-4229-a90b-116146bc5664', 'target': 'MarketingCluster', 'status': 'Completed', 'startTimeUtc': '2021-02-14T18:37:03.230101Z', 'endTimeUtc': '2021-02-14T19:09:15.376826Z', 'properties': {'ContentSnapshotId': 'f5c8967a-17aa-4504-b67a-fa799a512338', 'StepType': 'AutoMLStep', 'azureml.moduleid': '2ac9cab0-7563-4098-8f50-5c787585dc03', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'd0c23823', 'azureml.pipelinerunid': 'b6313294-a5f5-458e-a737-a1727fc5aa2e', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'MarketingCluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "f5091c60-1c3c-430f-8d81-d802f6bf2414", "resource_group": "aml-quickstarts-138899", "workspace_name": "quick-starts-ws-138899", "region": "southcentralus", "compute_target": "MarketingCluster", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["BernoulliNaiveBayes", "RandomForest", "ExtremeRandomTrees", "SGD", "LogisticRegression", "LinearSVM", "XGBoostClassifier", "KNN", "MultinomialNaiveBayes", "DecisionTree", "SVM", "TensorFlowLinearClassifier", "TensorFlowDNN", "GradientBoosting", "LightGBM", "AveragedPerceptronClassifier"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"c148bd1a-70ec-434f-a570-708c91fb8b7a\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'f5c8967a-17aa-4504-b67a-fa799a512338', 'SetupRunId': 'abe34885-9b26-4229-a90b-116146bc5664_setup', 'SetupRunContainerId': 'dcid.abe34885-9b26-4229-a90b-116146bc5664_setup', 'ClientSdkVersion': '1.20.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': 'abe34885-9b26-4229-a90b-116146bc5664_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampli ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'b6313294-a5f5-458e-a737-a1727fc5aa2e', 'status': 'Completed', 'startTimeUtc': '2021-02-14T18:36:37.27892Z', 'endTimeUtc': '2021-02-14T19:10:54.909322Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg138899.blob.core.windows.net/azureml/ExperimentRun/dcid.b6313294-a5f5-458e-a737-a1727fc5aa2e/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=V0e6Lq5O9f97t5oJauaaHld9DRsrgJVldUGgPoYwHwU%3D&st=2021-02-14T18%3A27%3A00Z&se=2021-02-15T02%3A37%3A00Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg138899.blob.core.windows.net/azureml/ExperimentRun/dcid.b6313294-a5f5-458e-a737-a1727fc5aa2e/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=eOqUXzoMzchtXd8EEpaok9x9DkvsfkWeoY02CuuwLSA%3D&st=2021-02-14T18%3A27%3A00Z&se=2021-02-15T02%3A37%3A00Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg138899.blob.core.windows.net/azureml/ExperimentRun/dcid.b6313294-a5f5-458e-a737-a1727fc5aa2e/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=VOlm9vFomyUOtuVIwMW9gp9tjJ8pQYRJYFlTsv604uY%3D&st=2021-02-14T18%3A27%3A00Z&se=2021-02-15T02%3A37%3A00Z&sp=r'}, 'submittedBy': 'ODL_User 138899'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/abe34885-9b26-4229-a90b-116146bc5664/metrics_data
# Downloaded azureml/abe34885-9b26-4229-a90b-116146bc5664/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  abe34885-9b26-4229-a90b-116146bc5664_0  \
# average_precision_score_macro                      [0.8151093723721079]
# matthews_correlation                               [0.5323740218566827]
# recall_score_micro                                 [0.9116843702579667]
# precision_score_micro                              [0.9116843702579667]
# recall_score_macro                                 [0.7513392683482543]
# AUC_weighted                                       [0.9450464668693167]
# accuracy                                           [0.9116843702579667]
# f1_score_weighted                                  [0.9091539479147899]
# precision_score_weighted                           [0.9072720074188747]
# average_precision_score_weighted                   [0.9531771295804466]
# average_precision_score_micro                      [0.9806603102489483]
# AUC_micro                                           [0.979695082216353]
# log_loss                                          [0.17775706110025447]
# recall_score_weighted                              [0.9116843702579667]
# AUC_macro                                          [0.9450464668693166]
# precision_score_macro                              [0.7819118765348991]
# weighted_accuracy                                  [0.9514937218005303]
# balanced_accuracy                                  [0.7513392683482543]
# f1_score_micro                                     [0.9116843702579667]
# f1_score_macro                                     [0.7653697272147331]
# norm_macro_recall                                  [0.5026785366965085]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_38  \
# average_precision_score_macro                       [0.8274185957418385]
# matthews_correlation                               [0.41044071569110546]
# recall_score_micro                                  [0.9077389984825494]
# precision_score_micro                               [0.9077389984825494]
# recall_score_macro                                  [0.6271522301689183]
# AUC_weighted                                        [0.9476027467041587]
# accuracy                                            [0.9077389984825494]
# f1_score_weighted                                   [0.8875836813004727]
# precision_score_weighted                            [0.8957301236051382]
# average_precision_score_weighted                    [0.9561559544226524]
# average_precision_score_micro                       [0.9801142860400277]
# AUC_micro                                           [0.9791125101029058]
# log_loss                                           [0.20102150680204686]
# recall_score_weighted                               [0.9077389984825494]
# AUC_macro                                           [0.9476027467041588]
# precision_score_macro                               [0.8312202642321538]
# weighted_accuracy                                   [0.9774011033111639]
# balanced_accuracy                                   [0.6271522301689183]
# f1_score_micro                                      [0.9077389984825494]
# f1_score_macro                                      [0.6710410509031199]
# norm_macro_recall                                   [0.2543044603378366]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_13  \
# average_precision_score_macro                       [0.7985126174047921]
# matthews_correlation                                [0.3976739324324451]
# recall_score_micro                                  [0.9062215477996965]
# precision_score_micro                               [0.9062215477996965]
# recall_score_macro                                  [0.6227454260188535]
# AUC_weighted                                        [0.9308878256246675]
# accuracy                                            [0.9062215477996965]
# f1_score_weighted                                    [0.885603431576398]
# precision_score_weighted                            [0.8929725418691179]
# average_precision_score_weighted                     [0.947605275820125]
# average_precision_score_micro                       [0.9766643355999638]
# AUC_micro                                           [0.9758990146932517]
# log_loss                                           [0.33655623030329523]
# recall_score_weighted                               [0.9062215477996965]
# AUC_macro                                           [0.9308878256246677]
# precision_score_macro                                [0.822098675416211]
# weighted_accuracy                                   [0.9766010009385309]
# balanced_accuracy                                   [0.6227454260188535]
# f1_score_micro                                      [0.9062215477996965]
# f1_score_macro                                      [0.6650154684677185]
# norm_macro_recall                                  [0.24549085203770704]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_31  \
# average_precision_score_macro                       [0.8013816819389603]
# matthews_correlation                                [0.4843785549832882]
# recall_score_micro                                  [0.9077389984825494]
# precision_score_micro                               [0.9077389984825494]
# recall_score_macro                                  [0.7124097197909778]
# AUC_weighted                                        [0.9348190320590832]
# accuracy                                            [0.9077389984825494]
# f1_score_weighted                                    [0.901734939171279]
# precision_score_weighted                            [0.8987262915460366]
# average_precision_score_weighted                    [0.9489850016507141]
# average_precision_score_micro                       [0.9780307267825393]
# AUC_micro                                           [0.9769387101899463]
# log_loss                                            [0.1957832423354532]
# recall_score_weighted                               [0.9077389984825494]
# AUC_macro                                           [0.9348190320590833]
# precision_score_macro                               [0.7761438892233594]
# weighted_accuracy                                   [0.9562339748140789]
# balanced_accuracy                                   [0.7124097197909778]
# f1_score_micro                                      [0.9077389984825494]
# f1_score_macro                                      [0.7384117513104482]
# norm_macro_recall                                  [0.42481943958195556]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_5  \
# average_precision_score_macro                       [0.743666883833878]
# matthews_correlation                              [0.33251442640070783]
# recall_score_micro                                 [0.8998482549317147]
# precision_score_micro                              [0.8998482549317147]
# recall_score_macro                                  [0.594290141466008]
# AUC_weighted                                       [0.9058835188488589]
# accuracy                                           [0.8998482549317147]
# f1_score_weighted                                  [0.8747405235455831]
# precision_score_weighted                           [0.8818172490263929]
# average_precision_score_weighted                    [0.932468672419057]
# average_precision_score_micro                      [0.9698202022480874]
# AUC_micro                                          [0.9690852696756248]
# log_loss                                          [0.23502433658847918]
# recall_score_weighted                              [0.8998482549317147]
# AUC_macro                                           [0.905883518848859]
# precision_score_macro                              [0.7931532449881074]
# weighted_accuracy                                  [0.9757100692981324]
# balanced_accuracy                                   [0.594290141466008]
# f1_score_micro                                     [0.8998482549317147]
# f1_score_macro                                     [0.6278156421827422]
# norm_macro_recall                                   [0.188580282932016]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_6  \
# average_precision_score_macro                      [0.7391246038814282]
# matthews_correlation                              [0.33340661446628406]
# recall_score_micro                                 [0.9001517450682853]
# precision_score_micro                              [0.9001517450682853]
# recall_score_macro                                 [0.5932768914155307]
# AUC_weighted                                       [0.8897808082660459]
# accuracy                                           [0.9001517450682853]
# f1_score_weighted                                  [0.8746567304785686]
# precision_score_weighted                           [0.8827113977984437]
# average_precision_score_weighted                   [0.9296212646789883]
# average_precision_score_micro                      [0.9671394444758956]
# AUC_micro                                          [0.9659423276634255]
# log_loss                                           [0.2519426729384864]
# recall_score_weighted                              [0.9001517450682853]
# AUC_macro                                          [0.8897808082660459]
# precision_score_macro                              [0.7979300898726163]
# weighted_accuracy                                  [0.9763404704059276]
# balanced_accuracy                                  [0.5932768914155307]
# f1_score_micro                                     [0.9001517450682853]
# f1_score_macro                                     [0.6267831475663812]
# norm_macro_recall                                  [0.1865537828310615]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_8  \
# average_precision_score_macro                      [0.7173547185341703]
# matthews_correlation                                              [0.0]
# recall_score_micro                                 [0.8880121396054628]
# precision_score_micro                              [0.8880121396054628]
# recall_score_macro                                                [0.5]
# AUC_weighted                                       [0.8672860088136084]
# accuracy                                           [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# precision_score_weighted                            [0.788565560086672]
# average_precision_score_weighted                    [0.920037559057929]
# average_precision_score_micro                      [0.9602566719580256]
# AUC_micro                                          [0.9610628141687065]
# log_loss                                           [0.2816255859525191]
# recall_score_weighted                              [0.8880121396054628]
# AUC_macro                                          [0.8672860088136083]
# precision_score_macro                              [0.4440060698027314]
# weighted_accuracy                                  [0.9843450583187134]
# balanced_accuracy                                                 [0.5]
# f1_score_micro                                     [0.8880121396054628]
# f1_score_macro                                     [0.4703423886834914]
# norm_macro_recall                                                 [0.0]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_21  \
# average_precision_score_macro                       [0.8131628841963428]
# matthews_correlation                                [0.5264365575296669]
# recall_score_micro                                  [0.9125948406676783]
# precision_score_micro                               [0.9125948406676783]
# recall_score_macro                                  [0.7411947273949842]
# AUC_weighted                                        [0.9424512871239444]
# accuracy                                            [0.9125948406676783]
# f1_score_weighted                                   [0.9087900123862012]
# precision_score_weighted                            [0.9064419404986112]
# average_precision_score_weighted                    [0.9524536910133203]
# average_precision_score_micro                       [0.9800107530929907]
# AUC_micro                                           [0.9790159827392864]
# log_loss                                           [0.18386077817913915]
# recall_score_weighted                               [0.9125948406676783]
# AUC_macro                                           [0.9424512871239443]
# precision_score_macro                               [0.7872528061629692]
# weighted_accuracy                                    [0.955148852498673]
# balanced_accuracy                                   [0.7411947273949842]
# f1_score_micro                                      [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
# norm_macro_recall                                   [0.4823894547899683]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_10  \
# average_precision_score_macro                        [0.742448759934101]
# matthews_correlation                                [0.4171929634639792]
# recall_score_micro                                  [0.7808801213960547]
# precision_score_micro                               [0.7808801213960547]
# recall_score_macro                                  [0.8008389414037681]
# AUC_weighted                                        [0.8820763105102001]
# accuracy                                            [0.7808801213960547]
# f1_score_weighted                                   [0.8173608678932456]
# precision_score_weighted                            [0.8991099460048715]
# average_precision_score_weighted                    [0.9293183756324995]
# average_precision_score_micro                       [0.8581385656510269]
# AUC_micro                                           [0.8603913134583369]
# log_loss                                            [0.5354322123396843]
# recall_score_weighted                               [0.7808801213960547]
# AUC_macro                                           [0.8820763105102001]
# precision_score_macro                               [0.6446371669436385]
# weighted_accuracy                                   [0.7759248862650855]
# balanced_accuracy                                   [0.8008389414037681]
# f1_score_micro                                      [0.7808801213960547]
# f1_score_macro                                      [0.6603216948405233]
# norm_macro_recall                                   [0.6016778828075362]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_22  ...  \
# average_precision_score_macro                       [0.8085204474402641]  ...
# matthews_correlation                                [0.5357619178216784]  ...
# recall_score_micro                                  [0.9128983308042489]  ...
# precision_score_micro                               [0.9128983308042489]  ...
# recall_score_macro                                  [0.7508386635472644]  ...
# AUC_weighted                                        [0.9448491887516278]  ...
# accuracy                                            [0.9128983308042489]  ...
# f1_score_weighted                                   [0.9100415644605403]  ...
# precision_score_weighted                            [0.9080335867085474]  ...
# average_precision_score_weighted                    [0.9516860732237478]  ...
# average_precision_score_micro                        [0.980352027134298]  ...
# AUC_micro                                           [0.9793693944704005]  ...
# log_loss                                           [0.18115151864375498]  ...
# recall_score_weighted                               [0.9128983308042489]  ...
# AUC_macro                                           [0.9448491887516277]  ...
# precision_score_macro                               [0.7860811293290488]  ...
# weighted_accuracy                                   [0.9531333625443325]  ...
# balanced_accuracy                                   [0.7508386635472644]  ...
# f1_score_micro                                      [0.9128983308042489]  ...
# f1_score_macro                                      [0.7668111420906795]  ...
# norm_macro_recall                                   [0.5016773270945287]  ...
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_39  \
# average_precision_score_macro                       [0.8247740011112449]
# matthews_correlation                                [0.5052027484693158]
# recall_score_micro                                    [0.91350531107739]
# precision_score_micro                                 [0.91350531107739]
# recall_score_macro                                  [0.7121040776368119]
# AUC_weighted                                        [0.9471591024864452]
# accuracy                                              [0.91350531107739]
# f1_score_weighted                                   [0.9060531061095253]
# precision_score_weighted                            [0.9039108506444806]
# average_precision_score_weighted                    [0.9555175191014692]
# average_precision_score_micro                       [0.9813132079770392]
# AUC_micro                                           [0.9804171953182387]
# log_loss                                           [0.19938965578511247]
# recall_score_weighted                                 [0.91350531107739]
# AUC_macro                                           [0.9471591024864452]
# precision_score_macro                               [0.8008308702791462]
# weighted_accuracy                                    [0.963507789529501]
# balanced_accuracy                                   [0.7121040776368119]
# f1_score_micro                                        [0.91350531107739]
# f1_score_macro                                      [0.7459246346571704]
# norm_macro_recall                                   [0.4242081552736239]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_1  \
# average_precision_score_macro                      [0.8065229883244922]
# matthews_correlation                                [0.488678780261868]
# recall_score_micro                                 [0.9071320182094081]
# precision_score_micro                              [0.9071320182094081]
# recall_score_macro                                 [0.7191727470931578]
# AUC_weighted                                       [0.9392346349984347]
# accuracy                                           [0.9071320182094081]
# f1_score_weighted                                  [0.9021127651963996]
# precision_score_weighted                           [0.8991976076061607]
# average_precision_score_weighted                   [0.9505970434373063]
# average_precision_score_micro                      [0.9791945367231853]
# AUC_micro                                          [0.9781770788959222]
# log_loss                                           [0.1874363495858499]
# recall_score_weighted                              [0.9071320182094081]
# AUC_macro                                          [0.9392346349984347]
# precision_score_macro                              [0.7723958081530135]
# weighted_accuracy                                  [0.9537972210153172]
# balanced_accuracy                                  [0.7191727470931578]
# f1_score_micro                                     [0.9071320182094081]
# f1_score_macro                                     [0.7416848907681176]
# norm_macro_recall                                 [0.43834549418631563]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_23  \
# average_precision_score_macro                       [0.8133385492316565]
# matthews_correlation                                 [0.526043819840976]
# recall_score_micro                                  [0.9113808801213961]
# precision_score_micro                               [0.9113808801213961]
# recall_score_macro                                  [0.7452477275968932]
# AUC_weighted                                        [0.9407795171594916]
# accuracy                                            [0.9113808801213961]
# f1_score_weighted                                   [0.9082878900933731]
# precision_score_weighted                            [0.9061410923608069]
# average_precision_score_weighted                    [0.9523124162348777]
# average_precision_score_micro                       [0.9794278430710546]
# AUC_micro                                           [0.9783950023141699]
# log_loss                                            [0.1922233799340996]
# recall_score_weighted                               [0.9113808801213961]
# AUC_macro                                           [0.9407795171594915]
# precision_score_macro                               [0.7820842654735272]
# weighted_accuracy                                   [0.9526272480674925]
# balanced_accuracy                                   [0.7452477275968932]
# f1_score_micro                                      [0.9113808801213961]
# f1_score_macro                                      [0.7618290845071816]
# norm_macro_recall                                  [0.49049545519378634]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_24  \
# average_precision_score_macro                       [0.8139690787708136]
# matthews_correlation                                 [0.505426697757936]
# recall_score_micro                                  [0.9092564491654022]
# precision_score_micro                               [0.9092564491654022]
# recall_score_macro                                  [0.7298419737444127]
# AUC_weighted                                        [0.9445453989741538]
# accuracy                                            [0.9092564491654022]
# f1_score_weighted                                   [0.9049706490476173]
# precision_score_weighted                            [0.9023434422530741]
# average_precision_score_weighted                     [0.952850005056871]
# average_precision_score_micro                       [0.9804513273312747]
# AUC_micro                                            [0.979487474699561]
# log_loss                                           [0.17905825648761967]
# recall_score_weighted                               [0.9092564491654022]
# AUC_macro                                           [0.9445453989741538]
# precision_score_macro                               [0.7778606346839009]
# weighted_accuracy                                   [0.9538002103329905]
# balanced_accuracy                                   [0.7298419737444127]
# f1_score_micro                                       [0.909256449165402]
# f1_score_macro                                      [0.7506214814254193]
# norm_macro_recall                                  [0.45968394748882546]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_34  \
# average_precision_score_macro                       [0.8131739740070394]
# matthews_correlation                                [0.5315622590944806]
# recall_score_micro                                  [0.9125948406676783]
# precision_score_micro                               [0.9125948406676783]
# recall_score_macro                                  [0.7471153863965161]
# AUC_weighted                                         [0.944934398079456]
# accuracy                                            [0.9125948406676783]
# f1_score_weighted                                   [0.9094206015141522]
# precision_score_weighted                            [0.9072764957020131]
# average_precision_score_weighted                    [0.9527044278048798]
# average_precision_score_micro                        [0.980516389708766]
# AUC_micro                                           [0.9795658571293699]
# log_loss                                           [0.18018846403036437]
# recall_score_weighted                               [0.9125948406676783]
# AUC_macro                                           [0.9449343980794559]
# precision_score_macro                               [0.7858567807269603]
# weighted_accuracy                                   [0.9536789130197086]
# balanced_accuracy                                   [0.7471153863965161]
# f1_score_micro                                      [0.9125948406676783]
# f1_score_macro                                      [0.7644825744504693]
# norm_macro_recall                                   [0.4942307727930322]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_35  \
# average_precision_score_macro                       [0.8004617629290862]
# matthews_correlation                                               [0.0]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                         [0.934374461653024]
# accuracy                                            [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_weighted                     [0.948588659974036]
# average_precision_score_micro                       [0.9755997293287618]
# AUC_micro                                           [0.9744062484888817]
# log_loss                                           [0.29313359336803707]
# recall_score_weighted                               [0.8880121396054628]
# AUC_macro                                           [0.9343744616530238]
# precision_score_macro                               [0.4440060698027314]
# weighted_accuracy                                   [0.9843450583187134]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# norm_macro_recall                                                  [0.0]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_20  \
# average_precision_score_macro                       [0.8156595912573914]
# matthews_correlation                                [0.5293167871387204]
# recall_score_micro                                  [0.9119878603945372]
# precision_score_micro                               [0.9119878603945372]
# recall_score_macro                                  [0.7467736228968578]
# AUC_weighted                                         [0.942659679501785]
# accuracy                                            [0.9119878603945372]
# f1_score_weighted                                   [0.9089160552297201]
# precision_score_weighted                             [0.906794600028807]
# average_precision_score_weighted                    [0.9530189915888272]
# average_precision_score_micro                       [0.9801024545227514]
# AUC_micro                                           [0.9791228260043612]
# log_loss                                           [0.18399704521283555]
# recall_score_weighted                               [0.9119878603945372]
# AUC_macro                                           [0.9426596795017848]
# precision_score_macro                               [0.7838393522957281]
# weighted_accuracy                                   [0.9530060865957042]
# balanced_accuracy                                   [0.7467736228968578]
# f1_score_micro                                      [0.9119878603945372]
# f1_score_macro                                      [0.7634603921475435]
# norm_macro_recall                                  [0.49354724579371556]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_29  \
# average_precision_score_macro                       [0.7553900166684868]
# matthews_correlation                                [0.5251231236528445]
# recall_score_micro                                  [0.8437025796661608]
# precision_score_micro                               [0.8437025796661608]
# recall_score_macro                                  [0.8551575724232977]
# AUC_weighted                                        [0.9243841310593556]
# accuracy                                            [0.8437025796661608]
# f1_score_weighted                                   [0.8659766953019384]
# precision_score_weighted                             [0.916629333047827]
# average_precision_score_weighted                    [0.9375460725043225]
# average_precision_score_micro                       [0.8829203161517626]
# AUC_micro                                           [0.9106004637550342]
# log_loss                                           [0.40265884070975505]
# recall_score_weighted                               [0.8437025796661608]
# AUC_macro                                           [0.9243841310593557]
# precision_score_macro                               [0.6941070079918361]
# weighted_accuracy                                    [0.840858614816875]
# balanced_accuracy                                   [0.8551575724232977]
# f1_score_micro                                      [0.8437025796661607]
# f1_score_macro                                       [0.730046113725129]
# norm_macro_recall                                   [0.7103151448465954]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_16  \
# average_precision_score_macro                       [0.7081780395596861]
# matthews_correlation                                [0.3592981102156134]
# recall_score_micro                                  [0.6959028831562974]
# precision_score_micro                               [0.6959028831562974]
# recall_score_macro                                  [0.7778588192580491]
# AUC_weighted                                        [0.8792671812569117]
# accuracy                                            [0.6959028831562974]
# f1_score_weighted                                   [0.7518922686652146]
# precision_score_weighted                            [0.8974257929837947]
# average_precision_score_weighted                    [0.9213513287926074]
# average_precision_score_micro                       [0.8661191630440576]
# AUC_micro                                           [0.8561190565555481]
# log_loss                                            [0.4799943232439283]
# recall_score_weighted                               [0.6959028831562974]
# AUC_macro                                           [0.8792671812569117]
# precision_score_macro                                [0.616151731614302]
# weighted_accuracy                                   [0.6755554410927934]
# balanced_accuracy                                   [0.7778588192580491]
# f1_score_micro                                      [0.6959028831562974]
# f1_score_macro                                      [0.5955987547500388]
# norm_macro_recall                                   [0.5557176385160982]
#
#                                  abe34885-9b26-4229-a90b-116146bc5664_18
# average_precision_score_macro                       [0.7254693119728348]
# matthews_correlation                                [0.3184121472144831]
# recall_score_micro                                  [0.7195751138088012]
# precision_score_micro                               [0.7195751138088012]
# recall_score_macro                                  [0.7390857965312394]
# AUC_weighted                                        [0.8634872473126646]
# accuracy                                            [0.7195751138088012]
# f1_score_weighted                                   [0.7696353140848133]
# precision_score_weighted                            [0.8807301195354366]
# average_precision_score_weighted                    [0.9230942074176679]
# average_precision_score_micro                       [0.8389398043977898]
# AUC_micro                                           [0.8327939744082749]
# log_loss                                            [0.5689221160018489]
# recall_score_weighted                               [0.7195751138088012]
# AUC_macro                                           [0.8634872473126646]
# precision_score_macro                               [0.6060145531067654]
# weighted_accuracy                                   [0.7147311390438577]
# balanced_accuracy                                   [0.7390857965312394]
# f1_score_micro                                      [0.7195751138088013]
# f1_score_macro                                      [0.5989634046104627]
# norm_macro_recall                                   [0.4781715930624788]
#
# [21 rows x 38 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/abe34885-9b26-4229-a90b-116146bc5664/model_data
# Downloaded azureml/abe34885-9b26-4229-a90b-116146bc5664/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                      oob_score=False,
#                                                                                                                                      random_state=None,
#                                                                                                                                      verbose=0,
#                                                                                                                                      warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.26666666666666666,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                      min_samples_split=0.10368421052631578,
#                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                      n_estimators=10,
#                                                                                      n_jobs=1,
#                                                                                      oob_score=False,
#                                                                                      random_state=None,
#                                                                                      verbose=0,
#                                                                                      warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.13333333333333333, 0.06666666666666667,
#                                          0.06666666666666667, 0.13333333333333333,
#                                          0.06666666666666667, 0.13333333333333333,
#                                          0.26666666666666666, 0.06666666666666667,
#                                          0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row0_col0" class="data row0 col0" >29183</td>
#                         <td id="T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row0_col1" class="data row0 col1" >75</td>
#             </tr>
#             <tr>
#                         <th id="T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row1_col0" class="data row1 col0" >2213</td>
#                         <td id="T_70fd6a46_6ef8_11eb_b7e8_c140e24317f0row1_col1" class="data row1 col1" >1479</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: bae94d21-7583-43fc-8775-dcb4e5384a27,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/f5091c60-1c3c-430f-8d81-d802f6bf2414/resourceGroups/aml-quickstarts-138899/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-138899/PipelineRuns/PipelineSubmit/bae94d21-7583-43fc-8775-dcb4e5384a27)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  59da9feb-48a1-458f-8e0d-e67d2b28859c

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
