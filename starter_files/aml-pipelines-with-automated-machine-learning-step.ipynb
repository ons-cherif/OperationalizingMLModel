# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.20.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-139016
# aml-quickstarts-139016
# southcentralus
# f9d5a085-54dc-4215-9ba6-dad5d86e60a0

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'BankMarketingExperiment'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: BankMarketingExperiment,
# Workspace: quick-starts-ws-139016)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "MarketingCluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketingDataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_BankMarketing',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_BankMarketing [99dd34f8][800daf5a-a195-4b4b-9731-5ce3f2b392f2], (This step will run and generate new outputs)
# Submitted PipelineRun eb7efd19-6cea-4fcd-be5f-58c8791e4d60
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/BankMarketingExperiment/runs/eb7efd19-6cea-4fcd-be5f-58c8791e4d60?wsid=/subscriptions/f9d5a085-54dc-4215-9ba6-dad5d86e60a0/resourcegroups/aml-quickstarts-139016/workspaces/quick-starts-ws-139016

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: eb7efd19-6cea-4fcd-be5f-58c8791e4d60
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/BankMarketingExperiment/runs/eb7efd19-6cea-4fcd-be5f-58c8791e4d60?wsid=/subscriptions/f9d5a085-54dc-4215-9ba6-dad5d86e60a0/resourcegroups/aml-quickstarts-139016/workspaces/quick-starts-ws-139016
# PipelineRun Status: Running
#
#
# StepRunId: 6c6a1810-76cd-49b3-9000-fc18e348ab2d
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/BankMarketingExperiment/runs/6c6a1810-76cd-49b3-9000-fc18e348ab2d?wsid=/subscriptions/f9d5a085-54dc-4215-9ba6-dad5d86e60a0/resourcegroups/aml-quickstarts-139016/workspaces/quick-starts-ws-139016
# StepRun( automl_BankMarketing ) Status: NotStarted
# StepRun( automl_BankMarketing ) Status: Running
#
# StepRun(automl_BankMarketing) Execution Summary
# ================================================
# StepRun( automl_BankMarketing ) Status: Finished
# {'runId': '6c6a1810-76cd-49b3-9000-fc18e348ab2d', 'target': 'MarketingCluster', 'status': 'Completed', 'startTimeUtc': '2021-02-16T13:02:47.892814Z', 'endTimeUtc': '2021-02-16T13:34:20.634207Z', 'properties': {'ContentSnapshotId': 'c0cfcdba-1ddc-4acd-a480-6784922fcf99', 'StepType': 'AutoMLStep', 'azureml.moduleid': '800daf5a-a195-4b4b-9731-5ce3f2b392f2', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '99dd34f8', 'azureml.pipelinerunid': 'eb7efd19-6cea-4fcd-be5f-58c8791e4d60', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'MarketingCluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "f9d5a085-54dc-4215-9ba6-dad5d86e60a0", "resource_group": "aml-quickstarts-139016", "workspace_name": "quick-starts-ws-139016", "region": "southcentralus", "compute_target": "MarketingCluster", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["KNN", "BernoulliNaiveBayes", "TensorFlowLinearClassifier", "SGD", "MultinomialNaiveBayes", "LinearSVM", "LightGBM", "LogisticRegression", "ExtremeRandomTrees", "RandomForest", "AveragedPerceptronClassifier", "XGBoostClassifier", "TensorFlowDNN", "SVM", "DecisionTree", "GradientBoosting"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"af7b3d44-1ffd-4313-a545-bad149f8f6b2\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'c0cfcdba-1ddc-4acd-a480-6784922fcf99', 'SetupRunId': '6c6a1810-76cd-49b3-9000-fc18e348ab2d_setup', 'SetupRunContainerId': 'dcid.6c6a1810-76cd-49b3-9000-fc18e348ab2d_setup', 'ClientSdkVersion': '1.20.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '6c6a1810-76cd-49b3-9000-fc18e348ab2d_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampli ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'eb7efd19-6cea-4fcd-be5f-58c8791e4d60', 'status': 'Completed', 'startTimeUtc': '2021-02-16T13:02:29.422421Z', 'endTimeUtc': '2021-02-16T13:35:54.866415Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg139016.blob.core.windows.net/azureml/ExperimentRun/dcid.eb7efd19-6cea-4fcd-be5f-58c8791e4d60/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=gFoMHmzv%2BLyxvrPQefibh0BYmLQENf6UVoL0fiGIRCo%3D&st=2021-02-16T12%3A52%3A51Z&se=2021-02-16T21%3A02%3A51Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg139016.blob.core.windows.net/azureml/ExperimentRun/dcid.eb7efd19-6cea-4fcd-be5f-58c8791e4d60/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=jcKMNGBJzcx%2BlJgxBwGq5FxQ%2FEXeY5ARDE%2BChZXgtN4%3D&st=2021-02-16T12%3A52%3A51Z&se=2021-02-16T21%3A02%3A51Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg139016.blob.core.windows.net/azureml/ExperimentRun/dcid.eb7efd19-6cea-4fcd-be5f-58c8791e4d60/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=pPyclzuhYYba%2Bb1NRFHvXwuU2tq90xuyLMMOf9wybQ0%3D&st=2021-02-16T12%3A52%3A51Z&se=2021-02-16T21%3A02%3A51Z&sp=r'}, 'submittedBy': 'ODL_User 139016'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/6c6a1810-76cd-49b3-9000-fc18e348ab2d/metrics_data
# Downloaded azureml/6c6a1810-76cd-49b3-9000-fc18e348ab2d/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_5  \
# average_precision_score_micro                      [0.9679229623181073]
# recall_score_macro                                 [0.5844753235638986]
# weighted_accuracy                                  [0.9773891460404707]
# precision_score_weighted                           [0.8817305826211965]
# AUC_macro                                          [0.8970638903244808]
# AUC_micro                                          [0.9673716326525913]
# AUC_weighted                                       [0.8970638903244809]
# average_precision_score_weighted                    [0.928298877087624]
# norm_macro_recall                                 [0.16895064712779728]
# matthews_correlation                              [0.31840025856976506]
# recall_score_micro                                 [0.8992412746585736]
# f1_score_macro                                     [0.6151437625947065]
# precision_score_macro                              [0.8000246710526315]
# f1_score_micro                                     [0.8992412746585736]
# f1_score_weighted                                  [0.8717447298668038]
# average_precision_score_macro                      [0.7299107069079883]
# precision_score_micro                              [0.8992412746585736]
# log_loss                                          [0.24223376959676549]
# recall_score_weighted                              [0.8992412746585736]
# accuracy                                           [0.8992412746585736]
# balanced_accuracy                                  [0.5844753235638986]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_34  \
# average_precision_score_micro                       [0.9802204735535665]
# recall_score_macro                                  [0.7567713629972936]
# weighted_accuracy                                   [0.9543123034451771]
# precision_score_weighted                            [0.9103936567676629]
# AUC_macro                                           [0.9436970104492569]
# AUC_micro                                           [0.9792477220969833]
# AUC_weighted                                         [0.943697010449257]
# average_precision_score_weighted                    [0.9529012007897981]
# norm_macro_recall                                   [0.5135427259945873]
# matthews_correlation                                [0.5476651690313282]
# recall_score_micro                                  [0.9150227617602428]
# f1_score_macro                                      [0.7727908552875257]
# precision_score_macro                               [0.7920274421073921]
# f1_score_micro                                      [0.9150227617602428]
# f1_score_weighted                                    [0.912294877094483]
# average_precision_score_macro                       [0.8146358499907052]
# precision_score_micro                               [0.9150227617602428]
# log_loss                                           [0.18212320322735842]
# recall_score_weighted                               [0.9150227617602428]
# accuracy                                            [0.9150227617602428]
# balanced_accuracy                                   [0.7567713629972936]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_32  \
# average_precision_score_micro                       [0.9793211817234202]
# recall_score_macro                                  [0.7425377004966222]
# weighted_accuracy                                   [0.9525423974350735]
# precision_score_weighted                            [0.9053097572540955]
# AUC_macro                                            [0.941137025861031]
# AUC_micro                                           [0.9784231868306466]
# AUC_weighted                                        [0.9411370258610308]
# average_precision_score_weighted                    [0.9514170948185521]
# norm_macro_recall                                   [0.4850754009932443]
# matthews_correlation                                [0.5217153406413008]
# recall_score_micro                                   [0.910773899848255]
# f1_score_macro                                      [0.7595759614181874]
# precision_score_macro                               [0.7805614303499377]
# f1_score_micro                                      [0.9107738998482551]
# f1_score_weighted                                   [0.9075335307123638]
# average_precision_score_macro                       [0.8097851285823288]
# precision_score_micro                                [0.910773899848255]
# log_loss                                           [0.19281962981552705]
# recall_score_weighted                                [0.910773899848255]
# accuracy                                             [0.910773899848255]
# balanced_accuracy                                   [0.7425377004966222]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_2  \
# average_precision_score_micro                      [0.9690185085202803]
# recall_score_macro                                  [0.537073930206151]
# weighted_accuracy                                  [0.9812020207327576]
# precision_score_weighted                           [0.8725230338164727]
# AUC_macro                                          [0.9038639651604992]
# AUC_micro                                          [0.9684895263665692]
# AUC_weighted                                       [0.9038639651604993]
# average_precision_score_weighted                   [0.9326840101685614]
# norm_macro_recall                                 [0.07414786041230204]
# matthews_correlation                              [0.20844058857303877]
# recall_score_micro                                 [0.8928679817905918]
# f1_score_macro                                     [0.5419951180692473]
# precision_score_macro                               [0.792978642425307]
# f1_score_micro                                     [0.8928679817905918]
# f1_score_weighted                                   [0.853084546826348]
# average_precision_score_macro                      [0.7480366279845687]
# precision_score_micro                              [0.8928679817905918]
# log_loss                                          [0.24005094785105513]
# recall_score_weighted                              [0.8928679817905918]
# accuracy                                           [0.8928679817905918]
# balanced_accuracy                                   [0.537073930206151]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_38  \
# average_precision_score_micro                       [0.9811325399365853]
# recall_score_macro                                  [0.7400105955946777]
# weighted_accuracy                                   [0.9554428403944659]
# precision_score_weighted                            [0.9062798949414683]
# AUC_macro                                           [0.9465246634694645]
# AUC_micro                                           [0.9802078377824497]
# AUC_weighted                                        [0.9465246634694645]
# average_precision_score_weighted                    [0.9543014019946383]
# norm_macro_recall                                   [0.4800211911893555]
# matthews_correlation                                [0.5254139610791995]
# recall_score_micro                                  [0.9125948406676783]
# f1_score_macro                                      [0.7607503025413473]
# precision_score_macro                                 [0.78754962860383]
# f1_score_micro                                      [0.9125948406676783]
# f1_score_weighted                                   [0.9086613440609772]
# average_precision_score_macro                       [0.8195150474299017]
# precision_score_micro                               [0.9125948406676783]
# log_loss                                            [0.1796168402131204]
# recall_score_weighted                               [0.9125948406676783]
# accuracy                                            [0.9125948406676783]
# balanced_accuracy                                   [0.7400105955946777]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_11  \
# average_precision_score_micro                       [0.8560688787420659]
# recall_score_macro                                  [0.8120374846947376]
# weighted_accuracy                                     [0.70609017138793]
# precision_score_weighted                            [0.9071285548719003]
# AUC_macro                                           [0.8862737960940785]
# AUC_micro                                           [0.8411111699567791]
# AUC_weighted                                        [0.8862737960940787]
# average_precision_score_weighted                    [0.9280152999448475]
# norm_macro_recall                                   [0.6240749693894752]
# matthews_correlation                                [0.4082642885726232]
# recall_score_micro                                  [0.7271623672230653]
# f1_score_macro                                      [0.6256235016339607]
# precision_score_macro                               [0.6335414313177558]
# f1_score_micro                                      [0.7271623672230653]
# f1_score_weighted                                   [0.7769258788550215]
# average_precision_score_macro                       [0.7330498659918498]
# precision_score_micro                               [0.7271623672230653]
# log_loss                                           [0.48517259841491045]
# recall_score_weighted                               [0.7271623672230653]
# accuracy                                            [0.7271623672230653]
# balanced_accuracy                                   [0.8120374846947376]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_17  \
# average_precision_score_micro                       [0.7959225199692773]
# recall_score_macro                                  [0.7362891708206214]
# weighted_accuracy                                   [0.7328520378580987]
# precision_score_weighted                            [0.8789333256621765]
# AUC_macro                                           [0.8165781230607931]
# AUC_micro                                           [0.8217427886552715]
# AUC_weighted                                         [0.816578123060793]
# average_precision_score_weighted                    [0.9070913489795073]
# norm_macro_recall                                   [0.4725783416412428]
# matthews_correlation                                [0.3194286889196668]
# recall_score_micro                                  [0.7335356600910471]
# f1_score_macro                                       [0.606734776216141]
# precision_score_macro                               [0.6079553148273528]
# f1_score_micro                                      [0.7335356600910471]
# f1_score_weighted                                   [0.7800270584545883]
# average_precision_score_macro                       [0.6950619932592608]
# precision_score_micro                               [0.7335356600910471]
# log_loss                                            [0.5770611334287372]
# recall_score_weighted                               [0.7335356600910471]
# accuracy                                            [0.7335356600910471]
# balanced_accuracy                                   [0.7362891708206214]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_14  \
# average_precision_score_micro                       [0.9680232121935288]
# recall_score_macro                                                 [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_weighted                             [0.788565560086672]
# AUC_macro                                           [0.8956935946666369]
# AUC_micro                                           [0.9667128886596466]
# AUC_weighted                                        [0.8956935946666369]
# average_precision_score_weighted                    [0.9312495718620591]
# norm_macro_recall                                                  [0.0]
# matthews_correlation                                               [0.0]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_macro                               [0.4440060698027314]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_macro                       [0.7427954490339954]
# precision_score_micro                               [0.8880121396054628]
# log_loss                                            [0.2596688610647086]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_22  \
# average_precision_score_micro                        [0.980352027134298]
# recall_score_macro                                  [0.7508386635472644]
# weighted_accuracy                                   [0.9531333625443325]
# precision_score_weighted                            [0.9080335867085474]
# AUC_macro                                           [0.9448491887516277]
# AUC_micro                                           [0.9793693944704005]
# AUC_weighted                                        [0.9448491887516278]
# average_precision_score_weighted                    [0.9516860732237478]
# norm_macro_recall                                   [0.5016773270945287]
# matthews_correlation                                [0.5357619178216784]
# recall_score_micro                                  [0.9128983308042489]
# f1_score_macro                                      [0.7668111420906795]
# precision_score_macro                               [0.7860811293290488]
# f1_score_micro                                      [0.9128983308042489]
# f1_score_weighted                                   [0.9100415644605403]
# average_precision_score_macro                       [0.8085204474402641]
# precision_score_micro                               [0.9128983308042489]
# log_loss                                           [0.18115151864375498]
# recall_score_weighted                               [0.9128983308042489]
# accuracy                                            [0.9128983308042489]
# balanced_accuracy                                   [0.7508386635472644]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_0  ...  \
# average_precision_score_micro                      [0.9806603102489483]  ...
# recall_score_macro                                 [0.7513392683482543]  ...
# weighted_accuracy                                  [0.9514937218005303]  ...
# precision_score_weighted                           [0.9072720074188747]  ...
# AUC_macro                                          [0.9450464668693166]  ...
# AUC_micro                                           [0.979695082216353]  ...
# AUC_weighted                                       [0.9450464668693167]  ...
# average_precision_score_weighted                   [0.9531771295804466]  ...
# norm_macro_recall                                  [0.5026785366965085]  ...
# matthews_correlation                               [0.5323740218566827]  ...
# recall_score_micro                                 [0.9116843702579667]  ...
# f1_score_macro                                     [0.7653697272147331]  ...
# precision_score_macro                              [0.7819118765348991]  ...
# f1_score_micro                                     [0.9116843702579667]  ...
# f1_score_weighted                                  [0.9091539479147899]  ...
# average_precision_score_macro                      [0.8151093723721079]  ...
# precision_score_micro                              [0.9116843702579667]  ...
# log_loss                                          [0.17775706110025447]  ...
# recall_score_weighted                              [0.9116843702579667]  ...
# accuracy                                           [0.9116843702579667]  ...
# balanced_accuracy                                  [0.7513392683482543]  ...
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_31  \
# average_precision_score_micro                       [0.9774270588941639]
# recall_score_macro                                   [0.628153439770898]
# weighted_accuracy                                   [0.9741218218235597]
# precision_score_weighted                            [0.8905400287071871]
# AUC_macro                                           [0.9342526678855305]
# AUC_micro                                           [0.9763752961792019]
# AUC_weighted                                        [0.9342526678855304]
# average_precision_score_weighted                    [0.9484874787008328]
# norm_macro_recall                                    [0.256306879541796]
# matthews_correlation                                [0.3966883845702862]
# recall_score_micro                                  [0.9053110773899848]
# f1_score_macro                                      [0.6696461623889437]
# precision_score_macro                               [0.8069790298533953]
# f1_score_micro                                      [0.9053110773899848]
# f1_score_weighted                                   [0.8861733588164185]
# average_precision_score_macro                       [0.7998616245795696]
# precision_score_micro                               [0.9053110773899848]
# log_loss                                           [0.20981680406070358]
# recall_score_weighted                               [0.9053110773899848]
# accuracy                                            [0.9053110773899848]
# balanced_accuracy                                    [0.628153439770898]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_9  \
# average_precision_score_micro                      [0.8022774897678302]
# recall_score_macro                                  [0.725499539684392]
# weighted_accuracy                                  [0.7063602447423365]
# precision_score_weighted                           [0.8764590047169176]
# AUC_macro                                          [0.8308303093283838]
# AUC_micro                                          [0.8229041565253834]
# AUC_weighted                                       [0.8308303093283838]
# average_precision_score_weighted                   [0.9146978280173055]
# norm_macro_recall                                  [0.4509990793687839]
# matthews_correlation                              [0.29923370677901306]
# recall_score_micro                                 [0.7101669195751138]
# f1_score_macro                                     [0.5888206143402686]
# precision_score_macro                              [0.5992693947380439]
# f1_score_micro                                     [0.7101669195751137]
# f1_score_weighted                                  [0.7621627944997652]
# average_precision_score_macro                      [0.7162529686203403]
# precision_score_micro                              [0.7101669195751138]
# log_loss                                           [0.5618885557373033]
# recall_score_weighted                              [0.7101669195751138]
# accuracy                                           [0.7101669195751138]
# balanced_accuracy                                   [0.725499539684392]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_26  \
# average_precision_score_micro                       [0.9790992488308239]
# recall_score_macro                                  [0.7159621151918969]
# weighted_accuracy                                   [0.9553520111267004]
# precision_score_weighted                            [0.8992110967163239]
# AUC_macro                                           [0.9389373285393825]
# AUC_micro                                           [0.9780497880404623]
# AUC_weighted                                        [0.9389373285393824]
# average_precision_score_weighted                     [0.950761405989792]
# norm_macro_recall                                   [0.4319242303837938]
# matthews_correlation                               [0.48767795941601105]
# recall_score_micro                                  [0.9077389984825494]
# f1_score_macro                                      [0.7405646205646206]
# precision_score_macro                               [0.7753142511695126]
# f1_score_micro                                      [0.9077389984825494]
# f1_score_weighted                                   [0.9021770532058848]
# average_precision_score_macro                       [0.8072509489251203]
# precision_score_micro                               [0.9077389984825494]
# log_loss                                            [0.1880124255406952]
# recall_score_weighted                               [0.9077389984825494]
# accuracy                                            [0.9077389984825494]
# balanced_accuracy                                   [0.7159621151918969]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_1  \
# average_precision_score_micro                      [0.9791945367231853]
# recall_score_macro                                 [0.7191727470931578]
# weighted_accuracy                                  [0.9537972210153172]
# precision_score_weighted                           [0.8991976076061607]
# AUC_macro                                          [0.9392346349984347]
# AUC_micro                                          [0.9781770788959222]
# AUC_weighted                                       [0.9392346349984347]
# average_precision_score_weighted                   [0.9505970434373063]
# norm_macro_recall                                 [0.43834549418631563]
# matthews_correlation                                [0.488678780261868]
# recall_score_micro                                 [0.9071320182094081]
# f1_score_macro                                     [0.7416848907681176]
# precision_score_macro                              [0.7723958081530135]
# f1_score_micro                                     [0.9071320182094081]
# f1_score_weighted                                  [0.9021127651963996]
# average_precision_score_macro                      [0.8065229883244922]
# precision_score_micro                              [0.9071320182094081]
# log_loss                                           [0.1874363495858499]
# recall_score_weighted                              [0.9071320182094081]
# accuracy                                           [0.9071320182094081]
# balanced_accuracy                                  [0.7191727470931578]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_6  \
# average_precision_score_micro                      [0.9689185248027298]
# recall_score_macro                                 [0.5860012188638632]
# weighted_accuracy                                  [0.9777679845686824]
# precision_score_weighted                           [0.8831869059979235]
# AUC_macro                                          [0.8978363314050092]
# AUC_micro                                          [0.9675291343623137]
# AUC_weighted                                       [0.8978363314050092]
# average_precision_score_weighted                   [0.9302037585917047]
# norm_macro_recall                                  [0.1720024377277265]
# matthews_correlation                               [0.3241515885151499]
# recall_score_micro                                 [0.8998482549317147]
# f1_score_macro                                     [0.6174621736634132]
# precision_score_macro                              [0.8054440789473685]
# f1_score_micro                                     [0.8998482549317147]
# f1_score_weighted                                  [0.8725173519760403]
# average_precision_score_macro                      [0.7363112597001651]
# precision_score_micro                              [0.8998482549317147]
# log_loss                                          [0.24547094703920647]
# recall_score_weighted                              [0.8998482549317147]
# accuracy                                           [0.8998482549317147]
# balanced_accuracy                                  [0.5860012188638632]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_35  \
# average_precision_score_micro                       [0.9795134837023285]
# recall_score_macro                                  [0.7251174869916847]
# weighted_accuracy                                   [0.9576250422959708]
# precision_score_weighted                             [0.903370071246511]
# AUC_macro                                           [0.9414121037997802]
# AUC_micro                                           [0.9785210036819478]
# AUC_weighted                                        [0.9414121037997804]
# average_precision_score_weighted                    [0.9509953630961461]
# norm_macro_recall                                   [0.4502349739833693]
# matthews_correlation                                [0.5083522940466384]
# recall_score_micro                                  [0.9113808801213961]
# f1_score_macro                                      [0.7508054908054907]
# precision_score_macro                               [0.7869857627630961]
# f1_score_micro                                      [0.9113808801213961]
# f1_score_weighted                                   [0.9060384853161786]
# average_precision_score_macro                       [0.8072128082907295]
# precision_score_micro                               [0.9113808801213961]
# log_loss                                           [0.18556097466121677]
# recall_score_weighted                               [0.9113808801213961]
# accuracy                                            [0.9113808801213961]
# balanced_accuracy                                   [0.7251174869916847]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_3  \
# average_precision_score_micro                      [0.8659730775433447]
# recall_score_macro                                  [0.781806233988519]
# weighted_accuracy                                  [0.7988344420444313]
# precision_score_weighted                            [0.892507976856135]
# AUC_macro                                          [0.8849386955933811]
# AUC_micro                                          [0.8757517828318531]
# AUC_weighted                                        [0.884938695593381]
# average_precision_score_weighted                   [0.9335117757118837]
# norm_macro_recall                                   [0.563612467977038]
# matthews_correlation                               [0.4033440449257153]
# recall_score_micro                                 [0.7954476479514416]
# f1_score_macro                                     [0.6648196377299805]
# precision_score_macro                              [0.6443247158468338]
# f1_score_micro                                     [0.7954476479514416]
# f1_score_weighted                                  [0.8271997165516994]
# average_precision_score_macro                      [0.7589351186656802]
# precision_score_micro                              [0.7954476479514416]
# log_loss                                           [0.5194019820408879]
# recall_score_weighted                              [0.7954476479514416]
# accuracy                                           [0.7954476479514416]
# balanced_accuracy                                   [0.781806233988519]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_21  \
# average_precision_score_micro                       [0.9800107530929907]
# recall_score_macro                                  [0.7411947273949842]
# weighted_accuracy                                    [0.955148852498673]
# precision_score_weighted                            [0.9064419404986112]
# AUC_macro                                           [0.9424512871239443]
# AUC_micro                                           [0.9790159827392864]
# AUC_weighted                                        [0.9424512871239444]
# average_precision_score_weighted                    [0.9524536910133203]
# norm_macro_recall                                   [0.4823894547899683]
# matthews_correlation                                [0.5264365575296669]
# recall_score_micro                                  [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
# precision_score_macro                               [0.7872528061629692]
# f1_score_micro                                      [0.9125948406676783]
# f1_score_weighted                                   [0.9087900123862012]
# average_precision_score_macro                       [0.8131628841963428]
# precision_score_micro                               [0.9125948406676783]
# log_loss                                           [0.18386077817913915]
# recall_score_weighted                               [0.9125948406676783]
# accuracy                                            [0.9125948406676783]
# balanced_accuracy                                   [0.7411947273949842]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_10  \
# average_precision_score_micro                       [0.8743967634381918]
# recall_score_macro                                  [0.8033706772474423]
# weighted_accuracy                                   [0.6995286190950485]
# precision_score_weighted                            [0.9045720946160348]
# AUC_macro                                           [0.8925366816894417]
# AUC_micro                                            [0.860641658281159]
# AUC_weighted                                        [0.8925366816894418]
# average_precision_score_weighted                    [0.9313967690507402]
# norm_macro_recall                                   [0.6067413544948845]
# matthews_correlation                               [0.39591387642295117]
# recall_score_micro                                  [0.7201820940819423]
# f1_score_macro                                      [0.6185166451856592]
# precision_score_macro                               [0.6291718426501035]
# f1_score_micro                                      [0.7201820940819423]
# f1_score_weighted                                   [0.7713435427916532]
# average_precision_score_macro                        [0.744512746777179]
# precision_score_micro                               [0.7201820940819423]
# log_loss                                            [0.4922338750963619]
# recall_score_weighted                               [0.7201820940819423]
# accuracy                                            [0.7201820940819423]
# balanced_accuracy                                   [0.8033706772474423]
#
#                                  6c6a1810-76cd-49b3-9000-fc18e348ab2d_29
# average_precision_score_micro                       [0.9731447587154589]
# recall_score_macro                                  [0.5355480349061864]
# weighted_accuracy                                   [0.9808231822045461]
# precision_score_weighted                            [0.8695836736674026]
# AUC_macro                                           [0.9198948961465008]
# AUC_micro                                           [0.9717761541490417]
# AUC_weighted                                        [0.9198948961465009]
# average_precision_score_weighted                    [0.9394936399877738]
# norm_macro_recall                                  [0.07109606981237282]
# matthews_correlation                                  [0.19986155439304]
# recall_score_micro                                  [0.8922610015174507]
# f1_score_macro                                      [0.5394001895597245]
# precision_score_macro                               [0.7809201762475664]
# f1_score_micro                                      [0.8922610015174507]
# f1_score_weighted                                   [0.8522521646553921]
# average_precision_score_macro                       [0.7664291214409948]
# precision_score_micro                               [0.8922610015174507]
# log_loss                                           [0.23050028531231823]
# recall_score_weighted                               [0.8922610015174507]
# accuracy                                            [0.8922610015174507]
# balanced_accuracy                                   [0.5355480349061864]
#
# [21 rows x 38 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/6c6a1810-76cd-49b3-9000-fc18e348ab2d/model_data
# Downloaded azureml/6c6a1810-76cd-49b3-9000-fc18e348ab2d/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                    n_estimators=10,
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    oob_score=False,
#                                                                                                                                    random_state=None,
#                                                                                                                                    verbose=0,
#                                                                                                                                    warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.26666666666666666,
#                                                                                          0.2,
#                                                                                          0.06666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                    min_samples_split=0.15052631578947367,
#                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                    n_estimators=10,
#                                                                                    n_jobs=1,
#                                                                                    oob_score=False,
#                                                                                    random_state=None,
#                                                                                    verbose=0,
#                                                                                    warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.26666666666666666, 0.2,
#                                          0.06666666666666667, 0.13333333333333333,
#                                          0.06666666666666667, 0.13333333333333333,
#                                          0.06666666666666667,
#                                          0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_f75315aa_705b_11eb_9cd8_03c7c00a1e4a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f75315aa_705b_11eb_9cd8_03c7c00a1e4alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow0_col0" class="data row0 col0" >28858</td>
#                         <td id="T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow0_col1" class="data row0 col1" >400</td>
#             </tr>
#             <tr>
#                         <th id="T_f75315aa_705b_11eb_9cd8_03c7c00a1e4alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow1_col0" class="data row1 col0" >1040</td>
#                         <td id="T_f75315aa_705b_11eb_9cd8_03c7c00a1e4arow1_col1" class="data row1 col1" >2652</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 786d9e11-73ee-4598-abab-829285033f9a,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/f9d5a085-54dc-4215-9ba6-dad5d86e60a0/resourceGroups/aml-quickstarts-139016/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-139016/PipelineRuns/PipelineSubmit/786d9e11-73ee-4598-abab-829285033f9a)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  b665ef94-d259-4186-9085-f84ea3ea2f44

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
